# %% [markdown]
# # **exercice 1**

# %%
import math

for i in range(-3,4):
            try :
        
                result=math.sin(i)/i
                print(result)
            except ZeroDivisionError : print("on ne peut divisez par zero")
# Out:
# 0.0470400026866224
# 0.45464871341284085
# 0.8414709848078965
# on ne peut divisez par zero
# 0.8414709848078965
# 0.45464871341284085
# 0.0470400026866224

# %% [markdown]
# # **exercice 2**

# %%
def Fonction(x):
    result=2*3+x-5
    return result

def poly(fonction,borninf,bornsup,touslesnbpas):
